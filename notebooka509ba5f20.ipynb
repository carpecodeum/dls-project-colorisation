# %%
# !cd /kaggle/working
# !git clone https://github.com/carpecodeum/dls-project-colorisation.git dls-proj
# Out:
# Cloning into 'dls-proj'...
# fatal: unable to access 'https://github.com/carpecodeum/dls-project-colorisation.git/': Could not resolve host: github.com
